# %%
import pandas as pd
import requests

# Load the financial statement dataset into a Pandas DataFrame
import os
import pandas as pd
import openai
openai.api_key = "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"
import xlrd  # dong nay de doc file xlsm
import glob
pd.set_option('display.max_columns',500,'float_format', '{:,.2f}'.format) #hien het cac dong, format dau phay, 2 so 0
pd.set_option('display.max_rows', 500)
#b = '../data/raw/niem_yet/xu_ly_file_excel/niem_yet_Q22022.xlsx' #path
read_BCTC = pd.read_excel('../data/raw/niem_yet/xu_ly_file_excel/niem_yet_Q22022.xlsx',sheet_name=0, header=None)
read_BCTC = read_BCTC.fillna(method='ffill')
read_BCTC.columns = read_BCTC.iloc[1]
BCTC = read_BCTC[2:]
BCTC.set_index('Ticker', inplace = True)
BCTC['Quarter'] = BCTC['Quarter'].map(str) + 'Q' + BCTC['Year'].map(str)
BCTC['Quarter'] = pd.to_datetime(BCTC['Quarter'], format='%mQ%Y').dt.to_period('Q')  # dt.to_period('Q') để chuyển qua format dạng quarter
BCTC.columns = BCTC.columns.str.replace(' Unit: VND billion','')
BCTC
# Out:
# /var/folders/1v/qp6912f958xf055vcq9kbnm00000gn/T/ipykernel_51356/4109369505.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BCTC['Quarter'] = BCTC['Quarter'].map(str) + 'Q' + BCTC['Year'].map(str)
# /var/folders/1v/qp6912f958xf055vcq9kbnm00000gn/T/ipykernel_51356/4109369505.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BCTC['Quarter'] = pd.to_datetime(BCTC['Quarter'], format='%mQ%Y').dt.to_period('Q')  # dt.to_period('Q') để chuyển qua format dạng quarter
# ...

# %%
prompt = f"groupby 'Sector - ICB Level 4' and 'Quarter' columns of BCTC"
#prompt = f"remove 'Unit: VND billion' in columns'name of BCTC  "
#prompt = f" find the median CURRENT ASSETS in summarize_dataset"
#prompt = f"find the median of 'CURRENT ASSETS' in {summarize_dataset}"
#prompt = f"analyse finance statements in the following dataframe:\n{summarize_dataset.head().to_string()}"
result = openai.Completion.create(
    engine="text-davinci-002",
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
    frequency_penalty=0,
    presence_penalty=0
)

# Display the result
print(result["choices"][0]["text"])
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Documents/PandasPython/statement_analyst_2/env/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
